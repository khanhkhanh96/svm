# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd


X1 = [0.3858, 0.4871, 0.9218 ,0.73, 0.17, 0.40, 0.93, 0.21]
X2 = [0.4687, 0.611,  0.41,   0.89, 0.05, 0.35, 0.81, 0.009]

# Basic chart
df=pd.DataFrame({'x': X2, 'y': X1 })
plt.plot( 'y', 'x', data=df, linestyle='none', marker='o')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py:3240: RuntimeWarning: Second argument 'x' is ambiguous: could be a color spec but is in data. Using as data.
# Either rename the entry in data or use three arguments to plot.
#   ret = ax.plot(*args, **kwargs)

# %%
# đường thẳng thứ nhất d1: đi qua A(0.21; 0.009) và B(0.4; 0.35)
# đường thẳng thứ 2: d2 đo qua C(0.4871; 0.611) và // d1
#d1: VTCP: u(0.19; 0.24) -> VTPT: (-0.24; 0.19) -> d1: (-0.24)(x1-0.21) + 0.19(x2-0.09) = 0
#d2: VTCP: u(0.19; 0.24) -> VTPT: (-0.24; 0.19) -> d1: (-0.24)(x1-0.21) + 0.19(x2-0.09) = 0
# -0.24X1 + 0.054 + 0.19x2 - 0.00171 <=> -0.24X1 + 0.19X2 + 0.05229 = <=> 1.26X2 + X1 >= 0.275
# -0.24X1 - 0.117 + 0.19x2 + 0.116 <=> -0.24X1 + 0.19X2 + 0.001 = <=> 1.26X2 + X1 <= 0.00526
# decision boundary: y = 1 if 1.26X2 + X1 >= 0.275    
#                    y =-1 if 1.26X2 + X1 <= 0.00526
#SVM: y = 0: 1.26X2 + X1 = 0.14

# %%
from IPython.display import Image
from IPython.core.display import HTML 
Image(filename ="svm1.png", width=800, height=800)

# %%
Image(filename ="svm2.png", width=800, height=800)
